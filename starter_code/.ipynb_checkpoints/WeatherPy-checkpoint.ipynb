# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests as rq
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 625

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+api_key

city_data=[]
record_count=1
set_count=1

print("Begin Data Retreival")
print("-------------------------")

for i, city in enumerate(cities):
    if (i%50==0 and i>=50):
        set_count+=1
        record_count=0
        
    city_url=base_url+"&q="+city
    
    print("Processing Record %s of set %s | %s" % (record_count, set_count, city))
    
    record_count+=1
    
    try:
        city_weather=rq.get(city_url).json()
        city_lat=city_weather["coord"]["lat"]
        city_lon=city_weather["coord"]["lon"]
        city_max_temp=city_weather["main"]["temp_max"]
        city_humidity=city_weather["main"]["humidity"]
        city_clouds=city_weather["clouds"]["all"]
        city_wind=city_weather["wind"]["speed"]
        city_country=city_weather["sys"]["country"]
        city_date=city_weather["dt"]
        
        city_data.append({"City":city,
                          "Cloudiness": city_clouds,
                          "Country": city_country,
                          "Date":city_date,
                          "Humidity":city_humidity,
                          "Lat": city_lat,
                          "Lon": city_lon,
                          "Max Temp": city_max_temp,
                          "Wind Speed":city_wind})
                         
                         
        
    except:
        print("City not found. skipping...")
        pass
    
print("-----------------")
print("Data Retreival Complete")
print("-----------------")
# Out:
# Begin Data Retreival
# -------------------------
# Processing Record 1 of set 1 | hilo
# Processing Record 2 of set 1 | jamestown
# Processing Record 3 of set 1 | sao filipe
# Processing Record 4 of set 1 | oriximina
# Processing Record 5 of set 1 | aklavik
# Processing Record 6 of set 1 | tumannyy
# City not found. skipping...
# Processing Record 7 of set 1 | kavieng
# Processing Record 8 of set 1 | rikitea
# Processing Record 9 of set 1 | bredasdorp
# Processing Record 10 of set 1 | grand river south east
# City not found. skipping...
# Processing Record 11 of set 1 | kadirli
# Processing Record 12 of set 1 | faanui
# Processing Record 13 of set 1 | vaini
# Processing Record 14 of set 1 | ushuaia
# Processing Record 15 of set 1 | buala
# Processing Record 16 of set 1 | malaba
# Processing Record 17 of set 1 | albany
# Processing Record 18 of set 1 | kaitangata
# Processing Record 19 of set 1 | manggar
# Processing Record 20 of set 1 | port-gentil
# Processing Record 21 of set 1 | dengfeng
# Processing Record 22 of set 1 | chokurdakh
# Processing Record 23 of set 1 | manyana
# Processing Record 24 of set 1 | huron
# Processing Record 25 of set 1 | chicama
# Processing Record 26 of set 1 | busselton
# Processing Record 27 of set 1 | laguna
# Processing Record 28 of set 1 | provideniya
# Processing Record 29 of set 1 | new norfolk
# Processing Record 30 of set 1 | mataura
# Processing Record 31 of set 1 | pimenteiras
# Processing Record 32 of set 1 | alpinopolis
# Processing Record 33 of set 1 | port hedland
# Processing Record 34 of set 1 | illoqqortoormiut
# City not found. skipping...
# Processing Record 35 of set 1 | dikson
# Processing Record 36 of set 1 | olafsvik
# City not found. skipping...
# Processing Record 37 of set 1 | deputatskiy
# Processing Record 38 of set 1 | carballo
# Processing Record 39 of set 1 | litovko
# Processing Record 40 of set 1 | hasaki
# Processing Record 41 of set 1 | hithadhoo
# Processing Record 42 of set 1 | kahului
# Processing Record 43 of set 1 | sorvag
# City not found. skipping...
# Processing Record 44 of set 1 | ormara
# Processing Record 45 of set 1 | punta arenas
# Processing Record 46 of set 1 | klaksvik
# Processing Record 47 of set 1 | mar del plata
# Processing Record 48 of set 1 | kapaa
# Processing Record 49 of set 1 | kamaishi
# Processing Record 50 of set 1 | atuona
# Processing Record 0 of set 2 | atambua
# Processing Record 1 of set 2 | mega
# Processing Record 2 of set 2 | samusu
# City not found. skipping...
# Processing Record 3 of set 2 | tsihombe
# City not found. skipping...
# Processing Record 4 of set 2 | narsaq
# Processing Record 5 of set 2 | tuatapere
# Processing Record 6 of set 2 | ippy
# Processing Record 7 of set 2 | debre zeyit
# City not found. skipping...
# Processing Record 8 of set 2 | puerto ayora
# Processing Record 9 of set 2 | araguacu
# City not found. skipping...
# Processing Record 10 of set 2 | cape town
# Processing Record 11 of set 2 | farafangana
# Processing Record 12 of set 2 | butaritari
# Processing Record 13 of set 2 | attawapiskat
# City not found. skipping...
# Processing Record 14 of set 2 | rantepao
# Processing Record 15 of set 2 | curup
# Processing Record 16 of set 2 | yulara
# Processing Record 17 of set 2 | salalah
# Processing Record 18 of set 2 | coari
# Processing Record 19 of set 2 | weligama
# Processing Record 20 of set 2 | labuhan
# Processing Record 21 of set 2 | puerto ayacucho
# Processing Record 22 of set 2 | bhatapara
# Processing Record 23 of set 2 | hermanus
# Processing Record 24 of set 2 | barrow
# Processing Record 25 of set 2 | belushya guba
# City not found. skipping...
# Processing Record 26 of set 2 | qaanaaq
# Processing Record 27 of set 2 | lagoa
# Processing Record 28 of set 2 | tasiilaq
# Processing Record 29 of set 2 | cerkezkoy
# Processing Record 30 of set 2 | vaitupu
# City not found. skipping...
# Processing Record 31 of set 2 | taolanaro
# City not found. skipping...
# Processing Record 32 of set 2 | grindavik
# Processing Record 33 of set 2 | aanekoski
# Processing Record 34 of set 2 | souillac
# Processing Record 35 of set 2 | ponta do sol
# Processing Record 36 of set 2 | cidreira
# Processing Record 37 of set 2 | bluff
# Processing Record 38 of set 2 | kloulklubed
# Processing Record 39 of set 2 | dunedin
# Processing Record 40 of set 2 | port lincoln
# Processing Record 41 of set 2 | airai
# Processing Record 42 of set 2 | lebu
# Processing Record 43 of set 2 | kushiro
# Processing Record 44 of set 2 | esperance
# Processing Record 45 of set 2 | aguimes
# Processing Record 46 of set 2 | bambous virieux
# Processing Record 47 of set 2 | vardo
# Processing Record 48 of set 2 | bengkulu
# City not found. skipping...
# Processing Record 49 of set 2 | gat
# Processing Record 0 of set 3 | lavrentiya
# Processing Record 1 of set 3 | ilulissat
# Processing Record 2 of set 3 | victoria
# Processing Record 3 of set 3 | valleyview
# Processing Record 4 of set 3 | bozoum
# Processing Record 5 of set 3 | nyanza
# Processing Record 6 of set 3 | carnarvon
# Processing Record 7 of set 3 | haapiti
# Processing Record 8 of set 3 | castro
# Processing Record 9 of set 3 | innsbruck
# Processing Record 10 of set 3 | port elizabeth
# Processing Record 11 of set 3 | tubuala
# Processing Record 12 of set 3 | hobart
# Processing Record 13 of set 3 | fairview
# Processing Record 14 of set 3 | ngukurr
# City not found. skipping...
# Processing Record 15 of set 3 | avarua
# Processing Record 16 of set 3 | severo-kurilsk
# Processing Record 17 of set 3 | arraial do cabo
# Processing Record 18 of set 3 | boguchany
# Processing Record 19 of set 3 | georgetown
# Processing Record 20 of set 3 | mishan
# Processing Record 21 of set 3 | sosva
# Processing Record 22 of set 3 | torbay
# Processing Record 23 of set 3 | puerto escondido
# Processing Record 24 of set 3 | college
# Processing Record 25 of set 3 | evensk
# Processing Record 26 of set 3 | riyadh
# Processing Record 27 of set 3 | barentsburg
# City not found. skipping...
# Processing Record 28 of set 3 | yellowknife
# Processing Record 29 of set 3 | burica
# City not found. skipping...
# Processing Record 30 of set 3 | tuktoyaktuk
# Processing Record 31 of set 3 | norsup
# Processing Record 32 of set 3 | touros
# Processing Record 33 of set 3 | husavik
# Processing Record 34 of set 3 | dzhusaly
# City not found. skipping...
# Processing Record 35 of set 3 | chuy
# Processing Record 36 of set 3 | talnakh
# Processing Record 37 of set 3 | muzhi
# Processing Record 38 of set 3 | bilma
# Processing Record 39 of set 3 | bilibino
# Processing Record 40 of set 3 | gurlan
# Processing Record 41 of set 3 | maniitsoq
# Processing Record 42 of set 3 | port alfred
# Processing Record 43 of set 3 | longonjo
# Processing Record 44 of set 3 | san nicolas
# Processing Record 45 of set 3 | calamar
# Processing Record 46 of set 3 | coihaique
# Processing Record 47 of set 3 | lyubytino
# Processing Record 48 of set 3 | naftah
# City not found. skipping...
# Processing Record 49 of set 3 | basco
# Processing Record 0 of set 4 | palabuhanratu
# City not found. skipping...
# Processing Record 1 of set 4 | amuntai
# Processing Record 2 of set 4 | khasan
# Processing Record 3 of set 4 | sentyabrskiy
# City not found. skipping...
# Processing Record 4 of set 4 | amapa
# Processing Record 5 of set 4 | aranos
# Processing Record 6 of set 4 | teguldet
# Processing Record 7 of set 4 | kavaratti
# Processing Record 8 of set 4 | cayenne
# Processing Record 9 of set 4 | yumen
# Processing Record 10 of set 4 | jind
# Processing Record 11 of set 4 | saint anthony
# Processing Record 12 of set 4 | umzimvubu
# City not found. skipping...
# Processing Record 13 of set 4 | biak
# Processing Record 14 of set 4 | formoso do araguaia
# City not found. skipping...
# Processing Record 15 of set 4 | palmar
# Processing Record 16 of set 4 | kruisfontein
# Processing Record 17 of set 4 | prince rupert
# Processing Record 18 of set 4 | naze
# Processing Record 19 of set 4 | saint-philippe
# Processing Record 20 of set 4 | coquimbo
# Processing Record 21 of set 4 | sao felix do xingu
# Processing Record 22 of set 4 | arlit
# Processing Record 23 of set 4 | keffi
# Processing Record 24 of set 4 | roatan
# Processing Record 25 of set 4 | pompeia
# Processing Record 26 of set 4 | katsuura
# Processing Record 27 of set 4 | adre
# Processing Record 28 of set 4 | amderma
# City not found. skipping...
# Processing Record 29 of set 4 | khani
# Processing Record 30 of set 4 | east london
# Processing Record 31 of set 4 | saleaula
# City not found. skipping...
# Processing Record 32 of set 4 | nelson bay
# Processing Record 33 of set 4 | port hardy
# Processing Record 34 of set 4 | barra patuca
# Processing Record 35 of set 4 | mapiri
# Processing Record 36 of set 4 | sao joao da barra
# Processing Record 37 of set 4 | bur gabo
# City not found. skipping...
# Processing Record 38 of set 4 | larvik
# Processing Record 39 of set 4 | yurgamysh
# Processing Record 40 of set 4 | vangaindrano
# Processing Record 41 of set 4 | mayo
# Processing Record 42 of set 4 | leningradskiy
# Processing Record 43 of set 4 | saldanha
# Processing Record 44 of set 4 | cherskiy
# Processing Record 45 of set 4 | channel-port aux basques
# Processing Record 46 of set 4 | opuwo
# Processing Record 47 of set 4 | san patricio
# Processing Record 48 of set 4 | kazalinsk
# City not found. skipping...
# Processing Record 49 of set 4 | isangel
# Processing Record 0 of set 5 | ilek
# Processing Record 1 of set 5 | pilar
# Processing Record 2 of set 5 | tarko-sale
# Processing Record 3 of set 5 | xichang
# Processing Record 4 of set 5 | kodiak
# Processing Record 5 of set 5 | upernavik
# Processing Record 6 of set 5 | woodland
# Processing Record 7 of set 5 | fort nelson
# Processing Record 8 of set 5 | zhuhai
# Processing Record 9 of set 5 | quchan
# Processing Record 10 of set 5 | killarney
# Processing Record 11 of set 5 | chiredzi
# Processing Record 12 of set 5 | puteyets
# Processing Record 13 of set 5 | nizhniy odes
# Processing Record 14 of set 5 | san buenaventura
# Processing Record 15 of set 5 | miri
# Processing Record 16 of set 5 | furth
# Processing Record 17 of set 5 | maragogi
# Processing Record 18 of set 5 | sorong
# Processing Record 19 of set 5 | aflu
# City not found. skipping...
# Processing Record 20 of set 5 | mwingi
# Processing Record 21 of set 5 | komsomolskiy
# Processing Record 22 of set 5 | longyearbyen
# Processing Record 23 of set 5 | lindsay
# Processing Record 24 of set 5 | moron
# Processing Record 25 of set 5 | woodstock
# Processing Record 26 of set 5 | sisimiut
# Processing Record 27 of set 5 | ostrovnoy
# Processing Record 28 of set 5 | hambantota
# Processing Record 29 of set 5 | koshurnikovo
# Processing Record 30 of set 5 | bubaque
# Processing Record 31 of set 5 | marienburg
# Processing Record 32 of set 5 | barbar
# City not found. skipping...
# Processing Record 33 of set 5 | devonport
# Processing Record 34 of set 5 | letlhakane
# Processing Record 35 of set 5 | wyszkow
# Processing Record 36 of set 5 | dryden
# Processing Record 37 of set 5 | hellvik
# Processing Record 38 of set 5 | amahai
# Processing Record 39 of set 5 | utiroa
# City not found. skipping...
# Processing Record 40 of set 5 | qingquan
# Processing Record 41 of set 5 | wanning
# Processing Record 42 of set 5 | kemi
# Processing Record 43 of set 5 | ulladulla
# Processing Record 44 of set 5 | vila franca do campo
# Processing Record 45 of set 5 | haibowan
# City not found. skipping...
# Processing Record 46 of set 5 | nantucket
# Processing Record 47 of set 5 | pinawa
# Processing Record 48 of set 5 | eldikan
# City not found. skipping...
# Processing Record 49 of set 5 | shingu
# Processing Record 0 of set 6 | muros
# Processing Record 1 of set 6 | bathsheba
# Processing Record 2 of set 6 | angatuba
# Processing Record 3 of set 6 | khatanga
# Processing Record 4 of set 6 | guarapari
# Processing Record 5 of set 6 | saint-joseph
# Processing Record 6 of set 6 | pueblo nuevo
# Processing Record 7 of set 6 | ambilobe
# Processing Record 8 of set 6 | luohe
# Processing Record 9 of set 6 | awbari
# Processing Record 10 of set 6 | chunan
# Processing Record 11 of set 6 | dubti
# Processing Record 12 of set 6 | tiksi
# Processing Record 13 of set 6 | tarudant
# City not found. skipping...
# Processing Record 14 of set 6 | banda aceh
# Processing Record 15 of set 6 | haines junction
# Processing Record 16 of set 6 | batagay-alyta
# Processing Record 17 of set 6 | viedma
# Processing Record 18 of set 6 | mount isa
# Processing Record 19 of set 6 | rungata
# City not found. skipping...
# Processing Record 20 of set 6 | araouane
# Processing Record 21 of set 6 | luanda
# Processing Record 22 of set 6 | tarauaca
# Processing Record 23 of set 6 | nueva loja
# Processing Record 24 of set 6 | hofn
# Processing Record 25 of set 6 | teguise
# Processing Record 26 of set 6 | luancheng
# Processing Record 27 of set 6 | saint george
# Processing Record 28 of set 6 | abong mbang
# Processing Record 29 of set 6 | marsh harbour
# Processing Record 30 of set 6 | sabang
# Processing Record 31 of set 6 | pacific grove
# Processing Record 32 of set 6 | smyshlyayevka
# Processing Record 33 of set 6 | itum-kale
# City not found. skipping...
# Processing Record 34 of set 6 | murdochville
# Processing Record 35 of set 6 | pochutla
# Processing Record 36 of set 6 | ancud
# Processing Record 37 of set 6 | wajir
# Processing Record 38 of set 6 | namibe
# Processing Record 39 of set 6 | vila velha
# Processing Record 40 of set 6 | sharjah
# Processing Record 41 of set 6 | warqla
# City not found. skipping...
# Processing Record 42 of set 6 | valentin gomez farias
# Processing Record 43 of set 6 | newport
# Processing Record 44 of set 6 | nesna
# Processing Record 45 of set 6 | seoul
# Processing Record 46 of set 6 | athabasca
# Processing Record 47 of set 6 | cabo san lucas
# Processing Record 48 of set 6 | tucuma
# City not found. skipping...
# Processing Record 49 of set 6 | broken hill
# Processing Record 0 of set 7 | nueve de julio
# Processing Record 1 of set 7 | saint peters
# Processing Record 2 of set 7 | lasa
# Processing Record 3 of set 7 | brae
# Processing Record 4 of set 7 | imbituba
# Processing Record 5 of set 7 | la paz
# Processing Record 6 of set 7 | codrington
# Processing Record 7 of set 7 | palu
# Processing Record 8 of set 7 | srednekolymsk
# Processing Record 9 of set 7 | nioro
# Processing Record 10 of set 7 | chincha alta
# Processing Record 11 of set 7 | fukue
# Processing Record 12 of set 7 | vermillion
# Processing Record 13 of set 7 | petropavlovsk-kamchatskiy
# Processing Record 14 of set 7 | kaohsiung
# Processing Record 15 of set 7 | sao joao del rei
# Processing Record 16 of set 7 | clyde river
# Processing Record 17 of set 7 | oktyabrskiy
# Processing Record 18 of set 7 | payakumbuh
# Processing Record 19 of set 7 | ilinsko-podomskoye
# City not found. skipping...
# Processing Record 20 of set 7 | yerofey pavlovich
# Processing Record 21 of set 7 | manokwari
# Processing Record 22 of set 7 | urengoy
# Processing Record 23 of set 7 | constitucion
# Processing Record 24 of set 7 | nuuk
# Processing Record 25 of set 7 | aban
# City not found. skipping...
# Processing Record 26 of set 7 | kyra
# City not found. skipping...
# Processing Record 27 of set 7 | hastings
# Processing Record 28 of set 7 | broome
# Processing Record 29 of set 7 | abu zabad
# Processing Record 30 of set 7 | malinyi
# Processing Record 31 of set 7 | marystown
# Processing Record 32 of set 7 | guerrero negro
# Processing Record 33 of set 7 | staryy nadym
# Processing Record 34 of set 7 | lompoc
# Processing Record 35 of set 7 | geresk
# City not found. skipping...
# Processing Record 36 of set 7 | pandan
# Processing Record 37 of set 7 | monrovia
# Processing Record 38 of set 7 | sinop
# Processing Record 39 of set 7 | ribeira grande
# Processing Record 40 of set 7 | ornskoldsvik
# Processing Record 41 of set 7 | tuggurt
# City not found. skipping...
# Processing Record 42 of set 7 | najran
# Processing Record 43 of set 7 | elko
# Processing Record 44 of set 7 | gardez
# Processing Record 45 of set 7 | vadso
# Processing Record 46 of set 7 | lumeje
# Processing Record 47 of set 7 | south lake tahoe
# Processing Record 48 of set 7 | fortuna
# Processing Record 49 of set 7 | martfu
# City not found. skipping...
# Processing Record 0 of set 8 | yambio
# City not found. skipping...
# Processing Record 1 of set 8 | itoman
# Processing Record 2 of set 8 | san gabriel
# Processing Record 3 of set 8 | okha
# Processing Record 4 of set 8 | son la
# Processing Record 5 of set 8 | sobolevo
# Processing Record 6 of set 8 | pisco
# Processing Record 7 of set 8 | timizart
# Processing Record 8 of set 8 | berdigestyakh
# Processing Record 9 of set 8 | ahipara
# Processing Record 10 of set 8 | debre birhan
# Processing Record 11 of set 8 | provost
# Processing Record 12 of set 8 | leshan
# Processing Record 13 of set 8 | nguiu
# City not found. skipping...
# Processing Record 14 of set 8 | thompson
# Processing Record 15 of set 8 | nanortalik
# Processing Record 16 of set 8 | lebyazhye
# Processing Record 17 of set 8 | norman wells
# Processing Record 18 of set 8 | saint-francois
# Processing Record 19 of set 8 | ayer itam
# City not found. skipping...
# Processing Record 20 of set 8 | aykhal
# Processing Record 21 of set 8 | ovre ardal
# Processing Record 22 of set 8 | san pedro
# Processing Record 23 of set 8 | tabiauea
# City not found. skipping...
# Processing Record 24 of set 8 | bethel
# Processing Record 25 of set 8 | tura
# Processing Record 26 of set 8 | arrecife
# City not found. skipping...
# Processing Record 27 of set 8 | ostrozska nova ves
# Processing Record 28 of set 8 | stropkov
# Processing Record 29 of set 8 | korla
# City not found. skipping...
# Processing Record 30 of set 8 | mahebourg
# Processing Record 31 of set 8 | pathein
# Processing Record 32 of set 8 | portland
# Processing Record 33 of set 8 | rio grande
# Processing Record 34 of set 8 | bacuit
# City not found. skipping...
# Processing Record 35 of set 8 | merauke
# Processing Record 36 of set 8 | sorland
# Processing Record 37 of set 8 | gorele
# Processing Record 38 of set 8 | nikolayevka
# Processing Record 39 of set 8 | lorengau
# Processing Record 40 of set 8 | pak phanang
# Processing Record 41 of set 8 | ondo
# Processing Record 42 of set 8 | fuerte olimpo
# Processing Record 43 of set 8 | safranbolu
# Processing Record 44 of set 8 | san juan
# Processing Record 45 of set 8 | chagda
# City not found. skipping...
# Processing Record 46 of set 8 | tessalit
# Processing Record 47 of set 8 | sataua
# City not found. skipping...
# Processing Record 48 of set 8 | marrakesh
# Processing Record 49 of set 8 | sola
# Processing Record 0 of set 9 | khorramshahr
# Processing Record 1 of set 9 | san ignacio
# Processing Record 2 of set 9 | maltahohe
# Processing Record 3 of set 9 | mango
# Processing Record 4 of set 9 | meulaboh
# Processing Record 5 of set 9 | matagami
# Processing Record 6 of set 9 | takoradi
# Processing Record 7 of set 9 | meridian
# Processing Record 8 of set 9 | saint-augustin
# Processing Record 9 of set 9 | rocha
# Processing Record 10 of set 9 | grand centre
# City not found. skipping...
# Processing Record 11 of set 9 | kamenskoye
# City not found. skipping...
# Processing Record 12 of set 9 | eregli
# Processing Record 13 of set 9 | adrar
# Processing Record 14 of set 9 | urucui
# Processing Record 15 of set 9 | hamilton
# Processing Record 16 of set 9 | ambon
# Processing Record 17 of set 9 | petauke
# Processing Record 18 of set 9 | moree
# Processing Record 19 of set 9 | manavalakurichi
# Processing Record 20 of set 9 | chapais
# Processing Record 21 of set 9 | dwarka
# Processing Record 22 of set 9 | kendari
# Processing Record 23 of set 9 | shelburne
# Processing Record 24 of set 9 | marawi
# Processing Record 25 of set 9 | columbus
# Processing Record 26 of set 9 | staszow
# Processing Record 27 of set 9 | domna
# Processing Record 28 of set 9 | ibaiti
# Processing Record 29 of set 9 | marzuq
# Processing Record 30 of set 9 | nikolskoye
# Processing Record 31 of set 9 | mahadday weyne
# City not found. skipping...
# Processing Record 32 of set 9 | tupancireta
# Processing Record 33 of set 9 | hirara
# Processing Record 34 of set 9 | caravelas
# Processing Record 35 of set 9 | pitimbu
# Processing Record 36 of set 9 | baraboo
# Processing Record 37 of set 9 | chipinge
# Processing Record 38 of set 9 | owensboro
# Processing Record 39 of set 9 | perisani
# Processing Record 40 of set 9 | acas
# Processing Record 41 of set 9 | atar
# Processing Record 42 of set 9 | ust-bolsheretsk
# City not found. skipping...
# Processing Record 43 of set 9 | cabedelo
# Processing Record 44 of set 9 | ahuimanu
# Processing Record 45 of set 9 | awjilah
# Processing Record 46 of set 9 | mount gambier
# Processing Record 47 of set 9 | mingshui
# Processing Record 48 of set 9 | saint-denis
# Processing Record 49 of set 9 | bonthe
# Processing Record 0 of set 10 | manaus
# Processing Record 1 of set 10 | alofi
# Processing Record 2 of set 10 | beaupre
# Processing Record 3 of set 10 | hay river
# Processing Record 4 of set 10 | wanlaweyn
# Processing Record 5 of set 10 | forio
# Processing Record 6 of set 10 | redmond
# Processing Record 7 of set 10 | pailitas
# Processing Record 8 of set 10 | safaga
# City not found. skipping...
# Processing Record 9 of set 10 | maceio
# Processing Record 10 of set 10 | avera
# Processing Record 11 of set 10 | saskylakh
# Processing Record 12 of set 10 | andevoranto
# City not found. skipping...
# Processing Record 13 of set 10 | prieska
# Processing Record 14 of set 10 | zolotkovo
# Processing Record 15 of set 10 | kirishi
# Processing Record 16 of set 10 | vestmannaeyjar
# Processing Record 17 of set 10 | ylivieska
# Processing Record 18 of set 10 | kununurra
# Processing Record 19 of set 10 | tondano
# Processing Record 20 of set 10 | geraldton
# Processing Record 21 of set 10 | los llanos de aridane
# Processing Record 22 of set 10 | horconcitos
# Processing Record 23 of set 10 | clemencia
# Processing Record 24 of set 10 | birjand
# Processing Record 25 of set 10 | camacha
# Processing Record 26 of set 10 | huanren
# Processing Record 27 of set 10 | shenjiamen
# Processing Record 28 of set 10 | poum
# Processing Record 29 of set 10 | rundu
# Processing Record 30 of set 10 | eyl
# Processing Record 31 of set 10 | bolungarvik
# City not found. skipping...
# Processing Record 32 of set 10 | gewane
# Processing Record 33 of set 10 | amparafaravola
# Processing Record 34 of set 10 | tyukhtet
# Processing Record 35 of set 10 | barda
# Processing Record 36 of set 10 | niksar
# Processing Record 37 of set 10 | kaspiyskiy
# Processing Record 38 of set 10 | piacabucu
# Processing Record 39 of set 10 | ujiie
# Processing Record 40 of set 10 | qaqortoq
# Processing Record 41 of set 10 | chengmai
# City not found. skipping...
# Processing Record 42 of set 10 | trinidad
# Processing Record 43 of set 10 | newton
# Processing Record 44 of set 10 | sangar
# Processing Record 45 of set 10 | bontang
# Processing Record 46 of set 10 | puerto carreno
# Processing Record 47 of set 10 | cap malheureux
# Processing Record 48 of set 10 | sao miguel do araguaia
# Processing Record 49 of set 10 | khonuu
# City not found. skipping...
# Processing Record 0 of set 11 | rio gallegos
# Processing Record 1 of set 11 | iqaluit
# Processing Record 2 of set 11 | mandal
# Processing Record 3 of set 11 | zhigansk
# Processing Record 4 of set 11 | guangyuan
# Processing Record 5 of set 11 | pachino
# Processing Record 6 of set 11 | sinnamary
# Processing Record 7 of set 11 | bull savanna
# Processing Record 8 of set 11 | norwich
# Processing Record 9 of set 11 | anadyr
# Processing Record 10 of set 11 | kirkwall
# Processing Record 11 of set 11 | hosur
# Processing Record 12 of set 11 | wamba
# Processing Record 13 of set 11 | sambava
# Processing Record 14 of set 11 | mehamn
# Processing Record 15 of set 11 | mezhgorye
# City not found. skipping...
# Processing Record 16 of set 11 | dobson
# Processing Record 17 of set 11 | arman
# Processing Record 18 of set 11 | suntar
# Processing Record 19 of set 11 | yichang
# Processing Record 20 of set 11 | huilong
# Processing Record 21 of set 11 | iraquara
# Processing Record 22 of set 11 | mollendo
# Processing Record 23 of set 11 | namatanai
# Processing Record 24 of set 11 | parabel
# Processing Record 25 of set 11 | lexington
# Processing Record 26 of set 11 | alugan
# Processing Record 27 of set 11 | boende
# Processing Record 28 of set 11 | sur
# Processing Record 29 of set 11 | taman
# Processing Record 30 of set 11 | xunchang
# Processing Record 31 of set 11 | synya
# Processing Record 32 of set 11 | pangnirtung
# Processing Record 33 of set 11 | santa marinella
# Processing Record 34 of set 11 | kralendijk
# Processing Record 35 of set 11 | pafos
# City not found. skipping...
# Processing Record 36 of set 11 | kerema
# Processing Record 37 of set 11 | sarkand
# Processing Record 38 of set 11 | zaragoza
# Processing Record 39 of set 11 | havelock
# Processing Record 40 of set 11 | muroto
# Processing Record 41 of set 11 | teahupoo
# Processing Record 42 of set 11 | sendafa
# Processing Record 43 of set 11 | tepalcingo
# Processing Record 44 of set 11 | kutum
# Processing Record 45 of set 11 | sernur
# Processing Record 46 of set 11 | ranong
# Processing Record 47 of set 11 | oyama
# Processing Record 48 of set 11 | kapit
# Processing Record 49 of set 11 | lucapa
# Processing Record 0 of set 12 | pevek
# Processing Record 1 of set 12 | porto novo
# Processing Record 2 of set 12 | paradwip
# City not found. skipping...
# Processing Record 3 of set 12 | mayya
# Processing Record 4 of set 12 | puri
# Processing Record 5 of set 12 | pombas
# Processing Record 6 of set 12 | kudahuvadhoo
# Processing Record 7 of set 12 | ofunato
# Processing Record 8 of set 12 | jesus maria
# Processing Record 9 of set 12 | hachinohe
# Processing Record 10 of set 12 | bisira
# Processing Record 11 of set 12 | marfino
# Processing Record 12 of set 12 | kawalu
# Processing Record 13 of set 12 | trincomalee
# Processing Record 14 of set 12 | copiapo
# Processing Record 15 of set 12 | lakes entrance
# Processing Record 16 of set 12 | waingapu
# Processing Record 17 of set 12 | grand gaube
# Processing Record 18 of set 12 | houma
# Processing Record 19 of set 12 | carbondale
# Processing Record 20 of set 12 | halifax
# Processing Record 21 of set 12 | bella union
# Processing Record 22 of set 12 | samarai
# Processing Record 23 of set 12 | nizwa
# Processing Record 24 of set 12 | baykit
# Processing Record 25 of set 12 | campoverde
# Processing Record 26 of set 12 | san cristobal
# Processing Record 27 of set 12 | iskele
# City not found. skipping...
# Processing Record 28 of set 12 | bagepalli
# Processing Record 29 of set 12 | derzhavinsk
# Processing Record 30 of set 12 | te anau
# Processing Record 31 of set 12 | benavente
# Processing Record 32 of set 12 | richards bay
# Processing Record 33 of set 12 | sitka
# Processing Record 34 of set 12 | iranshahr
# Processing Record 35 of set 12 | pemangkat
# City not found. skipping...
# Processing Record 36 of set 12 | comodoro rivadavia
# Processing Record 37 of set 12 | ransang
# City not found. skipping...
# Processing Record 38 of set 12 | luau
# Processing Record 39 of set 12 | belaya gora
# Processing Record 40 of set 12 | kiunga
# Processing Record 41 of set 12 | mys shmidta
# City not found. skipping...
# Processing Record 42 of set 12 | russell
# Processing Record 43 of set 12 | qasigiannguit
# Processing Record 44 of set 12 | anqing
# Processing Record 45 of set 12 | leshukonskoye
# Processing Record 46 of set 12 | muli
# Processing Record 47 of set 12 | genhe
# Processing Record 48 of set 12 | gizo
# Processing Record 49 of set 12 | coahuayana
# Processing Record 0 of set 13 | nyurba
# Processing Record 1 of set 13 | ciudad ojeda
# Processing Record 2 of set 13 | kirakira
# Processing Record 3 of set 13 | kasempa
# Processing Record 4 of set 13 | ovalle
# Processing Record 5 of set 13 | sungaipenuh
# Processing Record 6 of set 13 | briancon
# Processing Record 7 of set 13 | toliary
# City not found. skipping...
# Processing Record 8 of set 13 | karasburg
# Processing Record 9 of set 13 | jamnah
# City not found. skipping...
# Processing Record 10 of set 13 | zabaykalsk
# Processing Record 11 of set 13 | dongning
# Processing Record 12 of set 13 | niltepec
# Processing Record 13 of set 13 | potosi
# Processing Record 14 of set 13 | pokhara
# Processing Record 15 of set 13 | luderitz
# Processing Record 16 of set 13 | westport
# Processing Record 17 of set 13 | dubbo
# Processing Record 18 of set 13 | afyonkarahisar
# Processing Record 19 of set 13 | pahrump
# Processing Record 20 of set 13 | waipawa
# Processing Record 21 of set 13 | samalaeulu
# City not found. skipping...
# Processing Record 22 of set 13 | pingliang
# Processing Record 23 of set 13 | sarai
# Processing Record 24 of set 13 | haselunne
# -----------------
# Data Retreival Complete
# -----------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a data frame from the append

weather_data=pd.DataFrame(city_data)
weather_data=weather_data.drop_duplicates()
weather_data.to_csv('output_data/weather_data.csv')
# Display count of weather data values 
weather_data.count()
# Out:
# City          554
# Cloudiness    554
# Country       554
# Date          554
# Humidity      554
# Lat           554
# Lon           554
# Max Temp      554
# Wind Speed    554
# dtype: int64

# %%
weather_data.head()
# Out:
#          City  Cloudiness Country        Date  Humidity    Lat     Lon  \
# 0        hilo          90      US  1575507863        73  19.71 -155.08
# 1   jamestown           0      AU  1575507909        10 -33.21  138.60
# 2  sao filipe          93      CV  1575507909        84  14.90  -24.50
# 3   oriximina          12      BR  1575507909        61  -1.77  -55.87
# 4     aklavik          75      CA  1575507909        75  68.22 -135.01
#
#    Max Temp  Wind Speed
# 0     75.20        6.93
# 1     78.76       11.54
# 2     69.84       18.43
# 3     84.58        3.80
# 4    -11.20        5.82

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=40, edgecolors='black')
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=40, edgecolors='black')
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=40, edgecolors='black')
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=40, edgecolors='black')
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.show()
